# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([20,40,50,65,80])

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.plot(X,y_pred,color = 'blue',label = "Actual data",marker = 'o')
plt.xlabel("Hours Studies")
plt.ylabel("Test Score")
plt.legend()
plt.show()

# %%
mae = mean_absolute_error(y,y_pred)
mse = mean_squared_error (y,y_pred)
rmse = np.sqrt(mse)

# %%
print("Mean Absolute Error",mae)
print("Mean Squre error",mse)
print("Rmse",rmse)
# Out:
# Mean Absolute Error 1.4000000000000015
# Mean Squre error 3.4999999999999942
# Rmse 1.870828693386969
